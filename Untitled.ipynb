# %%
# !source /home/swapnil09/compressai_env/bin/activate

# %%
# %matplotlib inline
# !python3 tensorrt_main.py
# Out:
# 8.5.2.2
# 8.5.2.2
# Build_engine class is imported
# 8.5.2.2
# TensorRTInference class is imported
# engine path is: /home/swapnil09/DL_comp_final_09_24/tensorrt_scripts/engine_models/bmshj_gray_JETSON_FINETUNED_gray_UHD.engine
# Input shapes:
# Name: input, shape: (1, 1, 2464, 3280)
# Output shapes:
# Name : 279, Shape: (1, 192, 154, 205)
# Name : output, Shape: (1, 3, 2464, 3280)
# Engine is loaded from the disc
# ====================Engine done=============================
# Engine time: 2.51 seconds
# Running the inference_over_dataset
#
# NOT SAVING THE PROCESSED IMAGE FOR NOW
# Input image is: (8081920,)
# preprocess is done for: 000000_left.png time: 0.19 seconds
# Figure(1000x1000)
# Done for : 000000_left.png
# Input image is: (8081920,)
# preprocess is done for: 000001_left.png time: 0.18 seconds
# Figure(1000x1000)
# Done for : 000001_left.png
# Input image is: (8081920,)
# preprocess is done for: 000002_left.png time: 0.18 seconds
# Figure(1000x1000)
# ...
